# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content

# !wget -qO micromamba.tar.bz2 https://micro.mamba.pm/api/micromamba/linux-64/latest
# !tar -xjf micromamba.tar.bz2 bin/micromamba

# !./bin/micromamba create -y -p /content/mmdet_env python=3.10
# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install -U pip
# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install "setuptools<70" wheel ninja psutil
# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install "numpy==1.26.4" "yapf==0.40.1"

# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu121

# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install mmengine==0.10.7
# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install mmcv==2.1.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.1/index.html
# !/content/bin/micromamba run -p /content/mmdet_env python -m pip install mmdet==3.3.0 tifffile pycocotools opencv-python
# Out:
# /content
# Using Cached Shard Index for conda-forge/linux-64                                                   ✔ Done
# Using Cached Shard Index for conda-forge/noarch                                                     ✔ Done
# Fetching and Parsing Packages' Shards                                                     ✔ Done (0.2 sec)
# Using Cached Shard Index for conda-forge/linux-64                                                   ✔ Done
# Using Cached Shard Index for conda-forge/noarch                                                     ✔ Done
# Fetching and Parsing Packages' Shards                                                     ✔ Done (0.1 sec)
#
# Resolving Environment                                                                     ✔ Done (0.5 sec)
#
# Transaction
#
#   Prefix: /content/mmdet_env
#
#   Updating specs:
#
#    - python=3.10
#    - pip
#
#
#   Package               Version  Build                 Channel           Size
# ...

# %%
# %%bash
# /content/bin/micromamba run -p /content/mmdet_env python -m pip install "numpy==1.26.4" --force-reinstall
# /content/bin/micromamba run -p /content/mmdet_env python -c "
# import torch, numpy, mmcv, mmengine, mmdet
# print('torch', torch.__version__, torch.version.cuda)
# print('numpy', numpy.__version__)
# print('mmcv', mmcv.__version__)
# print('mmengine', mmengine.__version__)
# print('mmdet', mmdet.__version__)
# print('cuda', torch.cuda.is_available())
# "
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
# torch 2.1.2+cu121 12.1
# numpy 1.26.4
# mmcv 2.1.0
# mmengine 0.10.7
# mmdet 3.3.0
# cuda True
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# %%bash
# cd /content/drive/MyDrive/vis_hw3
# mkdir -p /content/hw3_data
# tar -xf hw3-data-release.tar -C /content/hw3_data
# find /content/hw3_data -maxdepth 3 -type d
# find /content/hw3_data -maxdepth 3 -type f | head
# Out:
# /content/hw3_data
# /content/hw3_data/train
# /content/hw3_data/train/b9ee49e3-4bef-4357-8384-9b5ed52ad398
# /content/hw3_data/train/80b9f836-8ad9-4afb-a58b-f5bb41696523
# /content/hw3_data/train/a6186101-9597-4a8f-b000-4e49ea15406c
# /content/hw3_data/train/7d2a1b5b-bdc8-4313-83cd-24804f4aa317
# /content/hw3_data/train/d9a735bb-660f-43ef-8bc3-4f0d6b3a1656
# /content/hw3_data/train/1ac7828d-31dd-450b-b7bb-4b47af993d5e
# /content/hw3_data/train/7a09aa24-d957-433e-979a-abfc486c1b93
# /content/hw3_data/train/a6211e46-edf8-46f1-8f57-3ea7f4c73467
# /content/hw3_data/train/4fefa26c-93f0-475b-a2c6-7b631431ddb0
# /content/hw3_data/train/af9e36a8-b38f-4968-a23c-740c869ac90f
# /content/hw3_data/train/dc5d1fe4-c142-4c5a-b262-290420eb00cc
# /content/hw3_data/train/0e661f91-df55-4ea7-88ee-072e79c780a7
# /content/hw3_data/train/109dc0df-e6a2-47c0-bf96-df35f0f099b9
# /content/hw3_data/train/485b3023-389b-4bd8-9312-bb9ccb392e0a
# /content/hw3_data/train/dcfa9c6d-cc2e-4330-85f5-60a2cb3b8f68
# ...

# %%
# %%bash
# /content/bin/micromamba run -p /content/mmdet_env python -m pip install imagecodecs
# Out:
# ...
#   Using cached imagecodecs-2025.3.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached imagecodecs-2025.3.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.4 MB)
# ...

# %%
# !MPLBACKEND=Agg /content/bin/micromamba run -p /content/mmdet_env python -u /content/drive/MyDrive/vis_hw3/swin_colab.py train
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# [ WARN:0@3691.868] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [ WARN:0@3692.267] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [ WARN:0@3692.579] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [ WARN:0@3697.256] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# ...

# %%
# %%bash
# grep -R "coco/segm_mAP_50" /content/drive/MyDrive/vis_hw3/output/swin/work | tail -20
# Out:
# /content/drive/MyDrive/vis_hw3/output/swin/work/20260510_041308/20260510_041308.log:2026/05/10 05:05:03 - mmengine - INFO - The best checkpoint with 0.5830 coco/segm_mAP_50 at 8 epoch is saved to best_coco_segm_mAP_50_epoch_8.pth.
# /content/drive/MyDrive/vis_hw3/output/swin/work/20260510_041308/20260510_041308.log:2026/05/10 05:10:49 - mmengine - INFO - Epoch(val) [9][31/31]    coco/bbox_mAP: 0.2440  coco/bbox_mAP_50: 0.5750  coco/bbox_mAP_75: 0.2210  coco/bbox_mAP_s: 0.3310  coco/bbox_mAP_m: 0.2000  coco/bbox_mAP_l: 0.0630  coco/segm_mAP: 0.2700  coco/segm_mAP_50: 0.5810  coco/segm_mAP_75: 0.3160  coco/segm_mAP_s: 0.2990  coco/segm_mAP_m: 0.2620  coco/segm_mAP_l: 0.4000  data_time: 1.5066  time: 2.4205
# ...

# %%
# !MPLBACKEND=Agg /content/bin/micromamba run -p /content/mmdet_env python -u /content/drive/MyDrive/vis_hw3/swin_colab.py val
# Out:
# ...
# Swin Mask R-CNN training / inference
# ...
# Mode:       val
# Train root: /content/hw3_data/train
# Test root:  /content/hw3_data/test_release
# Output dir: /content/drive/MyDrive/vis_hw3/output_exp
# Swin dir:   /content/drive/MyDrive/vis_hw3/output_exp/swin
# ...
# Running command
# ...
# /content/mmdet_env/bin/python /content/mmdet_env/lib/python3.10/site-packages/mmdet/.mim/tools/test.py /content/drive/MyDrive/vis_hw3/output_exp/swin/_runtime_swin_config.py /content/drive/MyDrive/vis_hw3/output_exp/swin/work/best_coco_segm_mAP_50_epoch_18.pth
# ...
# 05/10 16:56:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:42:22) [GCC 14.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 42
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.8, V12.8.93
# ...

# %%
# !MPLBACKEND=Agg /content/bin/micromamba run -p /content/mmdet_env python -u /content/drive/MyDrive/vis_hw3/swin_colab.py infer
# Out:
# ...
# Swin Mask R-CNN training / inference
# ...
# Mode:       infer
# Train root: /content/hw3_data/train
# Test root:  /content/hw3_data/test_release
# Output dir: /content/drive/MyDrive/vis_hw3/output_exp
# Swin dir:   /content/drive/MyDrive/vis_hw3/output_exp/swin
# ...
# Test COCO JSON generated
# ...
# Test images: 101
# Test JSON:   /content/drive/MyDrive/vis_hw3/output_exp/swin/test_coco.json
# ...
# Wrote inference config: /content/drive/MyDrive/vis_hw3/output_exp/swin/swin_maskrcnn_infer_config.py
# ...
# Running command
# ...
# /content/mmdet_env/bin/python /content/mmdet_env/lib/python3.10/site-packages/mmdet/.mim/tools/test.py /content/drive/MyDrive/vis_hw3/output_exp/swin/swin_maskrcnn_infer_config.py /content/drive/MyDrive/vis_hw3/output_exp/swin/work/best_coco_segm_mAP_50_epoch_18.pth
# ...
# 05/10 16:57:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
# ...
